# %%
# !pip install tensorflow==2.5.0

# %%
import tensorflow as tf
import numpy as np

# %%
input_1 = tf.keras.Input(shape = (224,224,3))
conv2d_1= tf.keras.layers.Conv2D(filters=32,kernel_size =(3,3),strides = (2,2),padding = 'same',use_bias =False)(input_1)
batch_normalization_1 = tf.keras.layers.BatchNormalization()(conv2d_1)
swish_1 =  tf.keras.layers.Activation('swish')(batch_normalization_1)
depthwise_conv2d_1 = tf.keras.layers.DepthwiseConv2D(kernel_size=(3,3),strides = (1,1),padding = 'same',depth_multiplier=1,dilation_rate=(1, 1),activation="linear",use_bias =False)(swish_1)
batch_normalization_2 = tf.keras.layers.BatchNormalization()(depthwise_conv2d_1)
swish_2 =  tf.keras.layers.Activation('swish')(batch_normalization_2)
global_1 = tf.keras.layers.GlobalAveragePooling2D()(swish_2)               
lambda_1 = tf.keras.layers.Reshape(target_shape= (1,1,32))(global_1)   
conv2d_2= tf.keras.layers.Conv2D(filters=8,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =True)(lambda_1)
swish_3 =  tf.keras.layers.Activation('swish')(conv2d_2)
conv2d_3= tf.keras.layers.Conv2D(filters=32,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =True)(swish_3)
activation_1 = tf.keras.layers.Activation('sigmoid')(conv2d_3)
multiply_1 =  tf.keras.layers.Multiply()([activation_1,swish_2]) 
conv2d_4 = tf.keras.layers.Conv2D(filters=16,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =False)(multiply_1)
batch_normalization_3 = tf.keras.layers.BatchNormalization()(conv2d_4)
conv2d_5 = tf.keras.layers.Conv2D(filters=96,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =False)(batch_normalization_3)
batch_normalization_4 = tf.keras.layers.BatchNormalization()(conv2d_5)
swish_4 =  tf.keras.layers.Activation('swish')(batch_normalization_4)
depthwise_conv2d_2 = tf.keras.layers.DepthwiseConv2D(kernel_size=(3,3),strides = (2,2),padding = 'same',depth_multiplier=1,dilation_rate=(1, 1),activation="linear",use_bias =False)(swish_4)
batch_normalization_5 = tf.keras.layers.BatchNormalization()(depthwise_conv2d_2)
swish_5 =  tf.keras.layers.Activation('swish')(batch_normalization_5)  
global_2 = tf.keras.layers.GlobalAveragePooling2D()(swish_5)               
lambda_2 = tf.keras.layers.Reshape(target_shape= (1,1,96))(global_2) 
conv2d_6 = tf.keras.layers.Conv2D(filters=4,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =True)(lambda_2)
swish_6 =  tf.keras.layers.Activation('swish')(conv2d_6) 
conv2d_7 = tf.keras.layers.Conv2D(filters=96,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =True)(swish_6)
activation_2 = tf.keras.layers.Activation('sigmoid')(conv2d_7)
multiply_2 =  tf.keras.layers.Multiply()([activation_2,swish_5]) 
conv2d_8 = tf.keras.layers.Conv2D(filters=24,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =False)(multiply_2)
batch_normalization_6 = tf.keras.layers.BatchNormalization()(conv2d_8)
conv2d_9 = tf.keras.layers.Conv2D(filters=144,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =False)(batch_normalization_6)
batch_normalization_7 = tf.keras.layers.BatchNormalization()(conv2d_9)
swish_7 =  tf.keras.layers.Activation('swish')(batch_normalization_7) 
depthwise_conv2d_3 = tf.keras.layers.DepthwiseConv2D(kernel_size=(3,3),strides = (1,1),padding = 'same',depth_multiplier=1,dilation_rate=(1, 1),activation="linear",use_bias =False)(swish_7)
batch_normalization_8 = tf.keras.layers.BatchNormalization()(depthwise_conv2d_3)
swish_8 =  tf.keras.layers.Activation('swish')(batch_normalization_8)
global_3 = tf.keras.layers.GlobalAveragePooling2D()(swish_8)               
lambda_3 = tf.keras.layers.Reshape(target_shape= (1,1,144))(global_3)
conv2d_10 = tf.keras.layers.Conv2D(filters=6,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =True)(lambda_3)
swish_9 =  tf.keras.layers.Activation('swish')(conv2d_10)
conv2d_11 = tf.keras.layers.Conv2D(filters=144,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =True)(swish_9)
activation_3 = tf.keras.layers.Activation('sigmoid')(conv2d_11)
multiply_3 =  tf.keras.layers.Multiply()([activation_3,swish_8]) 
conv2d_12 = tf.keras.layers.Conv2D(filters=24,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =False)(multiply_3)
batch_normalization_9 = tf.keras.layers.BatchNormalization()(conv2d_12)
drop_connect_1 = tf.keras.layers.Dropout(rate=0.0375)(batch_normalization_9)
add1 = tf.keras.layers.Add()([drop_connect_1, batch_normalization_6])
conv2d_13= tf.keras.layers.Conv2D(filters=144,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =False)(add1)
batch_normalization_10 = tf.keras.layers.BatchNormalization()(conv2d_13)
swish_10 =  tf.keras.layers.Activation('swish')(batch_normalization_10)
depthwise_conv2d_4 = tf.keras.layers.DepthwiseConv2D(kernel_size=(5,5),strides = (2,2),padding = 'same',depth_multiplier=1,dilation_rate=(1, 1),activation="linear",use_bias =False)(swish_10)
batch_normalization_11 = tf.keras.layers.BatchNormalization()(depthwise_conv2d_4)
swish_11 =  tf.keras.layers.Activation('swish')(batch_normalization_11)
global_4 = tf.keras.layers.GlobalAveragePooling2D()(swish_11)               
lambda_4 = tf.keras.layers.Reshape(target_shape= (1,1,144))(global_4)   
conv2d_14= tf.keras.layers.Conv2D(filters=6,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =True)(lambda_4)
swish_12 =  tf.keras.layers.Activation('swish')(conv2d_14)
conv2d_15= tf.keras.layers.Conv2D(filters=144,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =True)(swish_12)
activation_4 = tf.keras.layers.Activation('sigmoid')(conv2d_15)
multiply_4 =  tf.keras.layers.Multiply()([activation_4,swish_11]) 
conv2d_16 = tf.keras.layers.Conv2D(filters=40,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =False)(multiply_4)
batch_normalization_12 = tf.keras.layers.BatchNormalization()(conv2d_16)
conv2d_17 = tf.keras.layers.Conv2D(filters=240,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =False)(batch_normalization_12)
batch_normalization_13 = tf.keras.layers.BatchNormalization()(conv2d_17)
swish_13 =  tf.keras.layers.Activation('swish')(batch_normalization_13)
depthwise_conv2d_5 = tf.keras.layers.DepthwiseConv2D(kernel_size=(5,5),strides = (1,1),padding = 'same',depth_multiplier=1,dilation_rate=(1, 1),activation="linear",use_bias =False)(swish_13)
batch_normalization_14 = tf.keras.layers.BatchNormalization()(depthwise_conv2d_5)
swish_14 =  tf.keras.layers.Activation('swish')(batch_normalization_14)  
global_5 = tf.keras.layers.GlobalAveragePooling2D()(swish_14)               
lambda_5 = tf.keras.layers.Reshape(target_shape= (1,1,240))(global_5) 
conv2d_18 = tf.keras.layers.Conv2D(filters=10,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =True)(lambda_5)
swish_15 =  tf.keras.layers.Activation('swish')(conv2d_18) 
conv2d_19 = tf.keras.layers.Conv2D(filters=240,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =True)(swish_15)
activation_5 = tf.keras.layers.Activation('sigmoid')(conv2d_19)
multiply_5 =  tf.keras.layers.Multiply()([activation_5,swish_14]) 
conv2d_20 = tf.keras.layers.Conv2D(filters=40,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =False)(multiply_5)
batch_normalization_15 = tf.keras.layers.BatchNormalization()(conv2d_20)
drop_connect_2 = tf.keras.layers.Dropout(rate=0.0625)(batch_normalization_15)
add2 = tf.keras.layers.Add()([drop_connect_2, batch_normalization_12])
conv2d_21= tf.keras.layers.Conv2D(filters=240,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =False)(add2)
batch_normalization_16 = tf.keras.layers.BatchNormalization()(conv2d_21)
swish_16 =  tf.keras.layers.Activation('swish')(batch_normalization_16)
depthwise_conv2d_6 = tf.keras.layers.DepthwiseConv2D(kernel_size=(3,3),strides = (2,2),padding = 'same',depth_multiplier=1,dilation_rate=(1, 1),activation="linear",use_bias =False)(swish_16)
batch_normalization_17 = tf.keras.layers.BatchNormalization()(depthwise_conv2d_6)
swish_17 =  tf.keras.layers.Activation('swish')(batch_normalization_17)
global_6 = tf.keras.layers.GlobalAveragePooling2D()(swish_17)               
lambda_6 = tf.keras.layers.Reshape(target_shape= (1,1,240))(global_6)  
conv2d_22 = tf.keras.layers.Conv2D(filters=10,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =True)(lambda_6)
swish_18 =  tf.keras.layers.Activation('swish')(conv2d_22)
conv2d_23= tf.keras.layers.Conv2D(filters=240,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =True)(swish_18)
activation_6 = tf.keras.layers.Activation('sigmoid')(conv2d_23)
multiply_6 =  tf.keras.layers.Multiply()([activation_6,swish_17]) 
conv2d_24 = tf.keras.layers.Conv2D(filters=80,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =False)(multiply_6)
batch_normalization_18 = tf.keras.layers.BatchNormalization()(conv2d_24)
conv2d_25 = tf.keras.layers.Conv2D(filters=480,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =False)(batch_normalization_18)
batch_normalization_19 = tf.keras.layers.BatchNormalization()(conv2d_25)
swish_19 =  tf.keras.layers.Activation('swish')(batch_normalization_19)
depthwise_conv2d_7 = tf.keras.layers.DepthwiseConv2D(kernel_size=(3,3),strides = (1,1),padding = 'same',depth_multiplier=1,dilation_rate=(1, 1),activation="linear",use_bias =False)(swish_19)
batch_normalization_20 = tf.keras.layers.BatchNormalization()(depthwise_conv2d_7)
swish_20 =  tf.keras.layers.Activation('swish')(batch_normalization_20)  
global_7 = tf.keras.layers.GlobalAveragePooling2D()(swish_20)               
lambda_7 = tf.keras.layers.Reshape(target_shape= (1,1,480))(global_7) 
conv2d_26 = tf.keras.layers.Conv2D(filters=20,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =True)(lambda_7)
swish_21 =  tf.keras.layers.Activation('swish')(conv2d_26)
conv2d_27 = tf.keras.layers.Conv2D(filters=480,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =True)(swish_21)
activation_7 = tf.keras.layers.Activation('sigmoid')(conv2d_27)
multiply_7 =  tf.keras.layers.Multiply()([activation_7,swish_20]) 
conv2d_28 = tf.keras.layers.Conv2D(filters=80,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =False)(multiply_7)
batch_normalization_21 = tf.keras.layers.BatchNormalization()(conv2d_28)
drop_connect_3 = tf.keras.layers.Dropout(rate=0.0875)(batch_normalization_21)
add3 = tf.keras.layers.Add()([drop_connect_3, batch_normalization_18])
conv2d_29 = tf.keras.layers.Conv2D(filters=480,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =False)(add3)
batch_normalization_22 = tf.keras.layers.BatchNormalization()(conv2d_29)
swish_22 =  tf.keras.layers.Activation('swish')(batch_normalization_22) 
depthwise_conv2d_8 = tf.keras.layers.DepthwiseConv2D(kernel_size=(3,3),strides = (1,1),padding = 'same',depth_multiplier=1,dilation_rate=(1, 1),activation="linear",use_bias =False)(swish_22)
batch_normalization_23 = tf.keras.layers.BatchNormalization()(depthwise_conv2d_8)
swish_23 =  tf.keras.layers.Activation('swish')(batch_normalization_23)
global_8 = tf.keras.layers.GlobalAveragePooling2D()(swish_23)               
lambda_8 = tf.keras.layers.Reshape(target_shape= (1,1,480))(global_8)
conv2d_30 = tf.keras.layers.Conv2D(filters=20,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =True)(lambda_8)
swish_24 =  tf.keras.layers.Activation('swish')(conv2d_30)
conv2d_31 = tf.keras.layers.Conv2D(filters=480,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =True)(swish_24)
activation_8 = tf.keras.layers.Activation('sigmoid')(conv2d_31)
multiply_8 =  tf.keras.layers.Multiply()([activation_8,swish_23]) 
conv2d_32 = tf.keras.layers.Conv2D(filters=80,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =False)(multiply_8)
batch_normalization_24 = tf.keras.layers.BatchNormalization()(conv2d_32)
drop_connect_4 = tf.keras.layers.Dropout(rate=0.1)(batch_normalization_24)
add4 = tf.keras.layers.Add()([drop_connect_4, add3])
conv2d_33= tf.keras.layers.Conv2D(filters=480,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =False)(add4)
batch_normalization_25 = tf.keras.layers.BatchNormalization()(conv2d_33)
swish_25 =  tf.keras.layers.Activation('swish')(batch_normalization_25)
depthwise_conv2d_9 = tf.keras.layers.DepthwiseConv2D(kernel_size=(5,5),strides = (1,1),padding = 'same',depth_multiplier=1,dilation_rate=(1, 1),activation="linear",use_bias =False)(swish_25)
batch_normalization_26 = tf.keras.layers.BatchNormalization()(depthwise_conv2d_9)
swish_26 =  tf.keras.layers.Activation('swish')(batch_normalization_26)
global_9 = tf.keras.layers.GlobalAveragePooling2D()(swish_26)               
lambda_9 = tf.keras.layers.Reshape(target_shape= (1,1,480))(global_9)  
conv2d_34= tf.keras.layers.Conv2D(filters=20,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =True)(lambda_9)
swish_27 =  tf.keras.layers.Activation('swish')(conv2d_34)
conv2d_35= tf.keras.layers.Conv2D(filters=480,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =True)(swish_27)
activation_9 = tf.keras.layers.Activation('sigmoid')(conv2d_35)
multiply_9 =  tf.keras.layers.Multiply()([activation_9,swish_26]) 
conv2d_36  = tf.keras.layers.Conv2D(filters=112,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =False)(multiply_9)
batch_normalization_27 = tf.keras.layers.BatchNormalization()(conv2d_36)
conv2d_37 = tf.keras.layers.Conv2D(filters=672,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =False)(batch_normalization_27)
batch_normalization_28 = tf.keras.layers.BatchNormalization()(conv2d_37)
swish_28 =  tf.keras.layers.Activation('swish')(batch_normalization_28)
depthwise_conv2d_10 = tf.keras.layers.DepthwiseConv2D(kernel_size=(5,5),strides = (1,1),padding = 'same',depth_multiplier=1,dilation_rate=(1, 1),activation="linear",use_bias =False)(swish_28)
batch_normalization_29 = tf.keras.layers.BatchNormalization()(depthwise_conv2d_10)
swish_29 =  tf.keras.layers.Activation('swish')(batch_normalization_29)  
global_10 = tf.keras.layers.GlobalAveragePooling2D()(swish_29)               
lambda_10 = tf.keras.layers.Reshape(target_shape= (1,1,672))(global_10) 
conv2d_38  = tf.keras.layers.Conv2D(filters=28,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =True)(lambda_10)
swish_30 =  tf.keras.layers.Activation('swish')(conv2d_38) 
conv2d_39 = tf.keras.layers.Conv2D(filters=672,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =True)(swish_30)
activation_10 = tf.keras.layers.Activation('sigmoid')(conv2d_39)
multiply_10 =  tf.keras.layers.Multiply()([activation_10,swish_29]) 
conv2d_40 = tf.keras.layers.Conv2D(filters=112,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =False)(multiply_10)
batch_normalization_30 = tf.keras.layers.BatchNormalization()(conv2d_40)
drop_connect_5 = tf.keras.layers.Dropout(rate=0.125)(batch_normalization_30)
add5 = tf.keras.layers.Add()([drop_connect_5, batch_normalization_27])
conv2d_41 = tf.keras.layers.Conv2D(filters=672,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =False)(add5)
batch_normalization_31 = tf.keras.layers.BatchNormalization()(conv2d_41)
swish_31 =  tf.keras.layers.Activation('swish')(batch_normalization_31) 
depthwise_conv2d_11 = tf.keras.layers.DepthwiseConv2D(kernel_size=(5,5),strides = (1,1),padding = 'same',depth_multiplier=1,dilation_rate=(1, 1),activation="linear",use_bias =False)(swish_31)
batch_normalization_32 = tf.keras.layers.BatchNormalization()(depthwise_conv2d_11)
swish_32 =  tf.keras.layers.Activation('swish')(batch_normalization_32)
global_11 = tf.keras.layers.GlobalAveragePooling2D()(swish_32)               
lambda_11 = tf.keras.layers.Reshape(target_shape= (1,1,672))(global_11)
conv2d_42 = tf.keras.layers.Conv2D(filters=28,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =True)(lambda_11)
swish_33 =  tf.keras.layers.Activation('swish')(conv2d_42)
conv2d_43 = tf.keras.layers.Conv2D(filters=672,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =True)(swish_33)
activation_11 = tf.keras.layers.Activation('sigmoid')(conv2d_43)
multiply_11 =  tf.keras.layers.Multiply()([activation_11,swish_32]) 
conv2d_44 = tf.keras.layers.Conv2D(filters=112,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =False)(multiply_11)
batch_normalization_33 = tf.keras.layers.BatchNormalization()(conv2d_44)
drop_connect_6 = tf.keras.layers.Dropout(rate=0.1375)(batch_normalization_33)
add6 = tf.keras.layers.Add()([drop_connect_6, add5])
conv2d_45  = tf.keras.layers.Conv2D(filters=672,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =False)(add6)
batch_normalization_34 = tf.keras.layers.BatchNormalization()(conv2d_45)
swish_34 =  tf.keras.layers.Activation('swish')(batch_normalization_34)
depthwise_conv2d_12 = tf.keras.layers.DepthwiseConv2D(kernel_size=(5,5),strides = (2,2),padding = 'same',depth_multiplier=1,dilation_rate=(1, 1),activation="linear",use_bias =False)(swish_34)
batch_normalization_35 = tf.keras.layers.BatchNormalization()(depthwise_conv2d_12)
swish_35 =  tf.keras.layers.Activation('swish')(batch_normalization_35)
global_12 = tf.keras.layers.GlobalAveragePooling2D()(swish_35)               
lambda_12 = tf.keras.layers.Reshape(target_shape= (1,1,672))(global_12)
conv2d_46 = tf.keras.layers.Conv2D(filters=28,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =True)(lambda_12)
swish_36 =  tf.keras.layers.Activation('swish')(conv2d_46)
conv2d_47 = tf.keras.layers.Conv2D(filters=672,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =True)(swish_36)
activation_12 = tf.keras.layers.Activation('sigmoid')(conv2d_47)
multiply_12 =  tf.keras.layers.Multiply()([activation_12,swish_35]) 
conv2d_48 = tf.keras.layers.Conv2D(filters=192,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =False)(multiply_12)
batch_normalization_36 = tf.keras.layers.BatchNormalization()(conv2d_48)
conv2d_49  = tf.keras.layers.Conv2D(filters=1152,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =False)(batch_normalization_36)
batch_normalization_37 = tf.keras.layers.BatchNormalization()(conv2d_49)
swish_37 =  tf.keras.layers.Activation('swish')(batch_normalization_37)
depthwise_conv2d_13 = tf.keras.layers.DepthwiseConv2D(kernel_size=(5,5),strides = (1,1),padding = 'same',depth_multiplier=1,dilation_rate=(1, 1),activation="linear",use_bias =False)(swish_37)
batch_normalization_38 = tf.keras.layers.BatchNormalization()(depthwise_conv2d_13)
swish_38 =  tf.keras.layers.Activation('swish')(batch_normalization_38)
global_13 = tf.keras.layers.GlobalAveragePooling2D()(swish_38)               
lambda_13 = tf.keras.layers.Reshape(target_shape= (1,1,1152))(global_13)
conv2d_50 = tf.keras.layers.Conv2D(filters=48,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =True)(lambda_13)
swish_39 =  tf.keras.layers.Activation('swish')(conv2d_50)
conv2d_51 = tf.keras.layers.Conv2D(filters=1152,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =True)(swish_39)
activation_13 = tf.keras.layers.Activation('sigmoid')(conv2d_51)
multiply_13 =  tf.keras.layers.Multiply()([activation_13,swish_38]) 
conv2d_52 = tf.keras.layers.Conv2D(filters=192,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =False)(multiply_13)
batch_normalization_39 = tf.keras.layers.BatchNormalization()(conv2d_52)
drop_connect_7 = tf.keras.layers.Dropout(rate=0.1625)(batch_normalization_39)
add7 = tf.keras.layers.Add()([drop_connect_7, batch_normalization_36])
conv2d_53  = tf.keras.layers.Conv2D(filters=1152,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =False)(add7)
batch_normalization_40 = tf.keras.layers.BatchNormalization()(conv2d_53)
swish_40 =  tf.keras.layers.Activation('swish')(batch_normalization_40)
depthwise_conv2d_14 = tf.keras.layers.DepthwiseConv2D(kernel_size=(5,5),strides = (1,1),padding = 'same',depth_multiplier=1,dilation_rate=(1, 1),activation="linear",use_bias =False)(swish_40)
batch_normalization_41 = tf.keras.layers.BatchNormalization()(depthwise_conv2d_14)
swish_41 =  tf.keras.layers.Activation('swish')(batch_normalization_41)
global_14 = tf.keras.layers.GlobalAveragePooling2D()(swish_41)               
lambda_14 = tf.keras.layers.Reshape(target_shape= (1,1,1152))(global_14)
conv2d_54 = tf.keras.layers.Conv2D(filters=48,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =True)(lambda_14)
swish_42 =  tf.keras.layers.Activation('swish')(conv2d_54)
conv2d_55 = tf.keras.layers.Conv2D(filters=1152,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =True)(swish_42)
activation_14 = tf.keras.layers.Activation('sigmoid')(conv2d_55)
multiply_14 =  tf.keras.layers.Multiply()([activation_14,swish_41]) 
conv2d_56 = tf.keras.layers.Conv2D(filters=192,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =False)(multiply_14)
batch_normalization_42 = tf.keras.layers.BatchNormalization()(conv2d_56)
drop_connect_8 = tf.keras.layers.Dropout(rate=0.175)(batch_normalization_42)
add8 = tf.keras.layers.Add()([drop_connect_8, add7])
conv2d_57  = tf.keras.layers.Conv2D(filters=1152,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =False)(add8)
batch_normalization_43 = tf.keras.layers.BatchNormalization()(conv2d_57)
swish_43 =  tf.keras.layers.Activation('swish')(batch_normalization_43)
depthwise_conv2d_15 = tf.keras.layers.DepthwiseConv2D(kernel_size=(5,5),strides = (1,1),padding = 'same',depth_multiplier=1,dilation_rate=(1, 1),activation="linear",use_bias =False)(swish_43)
batch_normalization_44 = tf.keras.layers.BatchNormalization()(depthwise_conv2d_15)
swish_44 =  tf.keras.layers.Activation('swish')(batch_normalization_44)
global_15 = tf.keras.layers.GlobalAveragePooling2D()(swish_44)               
lambda_15 = tf.keras.layers.Reshape(target_shape= (1,1,1152))(global_15)
conv2d_58 = tf.keras.layers.Conv2D(filters=48,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =True)(lambda_15)
swish_45 =  tf.keras.layers.Activation('swish')(conv2d_58)
conv2d_59 = tf.keras.layers.Conv2D(filters=1152,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =True)(swish_45)
activation_15 = tf.keras.layers.Activation('sigmoid')(conv2d_59)
multiply_15 =  tf.keras.layers.Multiply()([activation_15,swish_44]) 
conv2d_60 = tf.keras.layers.Conv2D(filters=192,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =False)(multiply_15)
batch_normalization_45 = tf.keras.layers.BatchNormalization()(conv2d_60)
drop_connect_9 = tf.keras.layers.Dropout(rate=0.1875)(batch_normalization_45)
add9 = tf.keras.layers.Add()([drop_connect_9, add8])
conv2d_61  = tf.keras.layers.Conv2D(filters=1152,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =False)(add9)
batch_normalization_46 = tf.keras.layers.BatchNormalization()(conv2d_61)
swish_46 =  tf.keras.layers.Activation('swish')(batch_normalization_46)
depthwise_conv2d_16 = tf.keras.layers.DepthwiseConv2D(kernel_size=(3,3),strides = (1,1),padding = 'same',depth_multiplier=1,dilation_rate=(1, 1),activation="linear",use_bias =False)(swish_46)
batch_normalization_47 = tf.keras.layers.BatchNormalization()(depthwise_conv2d_16)
swish_47 =  tf.keras.layers.Activation('swish')(batch_normalization_47)
global_16 = tf.keras.layers.GlobalAveragePooling2D()(swish_47)               
lambda_16 = tf.keras.layers.Reshape(target_shape= (1,1,1152))(global_16)
conv2d_62 = tf.keras.layers.Conv2D(filters=48,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =True)(lambda_16)
swish_48 =  tf.keras.layers.Activation('swish')(conv2d_62)
conv2d_63 = tf.keras.layers.Conv2D(filters=1152,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =True)(swish_48)
activation_16 = tf.keras.layers.Activation('sigmoid')(conv2d_63)
multiply_16 =  tf.keras.layers.Multiply()([activation_16,swish_47]) 
conv2d_64 = tf.keras.layers.Conv2D(filters=320,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =False)(multiply_16)
batch_normalization_48 = tf.keras.layers.BatchNormalization()(conv2d_64)
conv2d_65  = tf.keras.layers.Conv2D(filters=1280,kernel_size =(1,1),strides = (1,1),padding = 'same',use_bias =False)(batch_normalization_48)
batch_normalization_49 = tf.keras.layers.BatchNormalization()(conv2d_65)
swish_49 =  tf.keras.layers.Activation('swish')(batch_normalization_49)
out = tf.keras.layers.GlobalAveragePooling2D()(swish_49)
fc_yaw = tf.keras.layers.Dense(name='yaw_new',activation='softmax', units=120)(out)
fc_pitch = tf.keras.layers.Dense(name='pitch_new', activation='softmax',units=66)(out)
fc_roll = tf.keras.layers.Dense(name='roll_new', activation='softmax',units=66)(out)


model = tf.keras.models.Model(inputs=input_1, outputs=[fc_yaw, fc_pitch, fc_roll])

# %%
model.load_weights('WHENet.h5')

# %%
model.save('pose_model.h5')

# %%
model.summary()
